# %%
import dask.dataframe as dd
from dask.diagnostics import ProgressBar

# %%
df = dd.read_csv("./archive/Parking_Violations_Issued_-_Fiscal_Year_2017.csv")

# %%
df
# Out:
# Dask DataFrame Structure:
#                Summons Number Plate ID Registration State Plate Type Issue Date Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1 Street Code2 Street Code3 Vehicle Expiration Date Violation Location Violation Precinct Issuer Precinct Issuer Code Issuer Command Issuer Squad Violation Time Time First Observed Violation County Violation In Front Of Or Opposite House Number Street Name Intersecting Street Date First Observed Law Section Sub Division Violation Legal Code Days Parking In Effect     From Hours In Effect To Hours In Effect Vehicle Color Unregistered Vehicle? Vehicle Year Meter Number Feet From Curb Violation Post Code Violation Description No Standing or Stopping Violation Hydrant Violation Double Parking Violation
# npartitions=33
# ...

# %%
missing_values = df.isnull().sum()

# %%
missing_values
# Out:
# Dask Series Structure:
# npartitions=1
# Date First Observed    int64
# Violation Time           ...
# dtype: int64
# Dask Name: dataframe-sum-agg, 100 tasks

# %%
missing_count = ((missing_values/df.index.size)*100)

# %%
missing_count
# Out:
# Dask Series Structure:
# npartitions=1
# Date First Observed    float64
# Violation Time             ...
# dtype: float64
# Dask Name: mul, 169 tasks

# %%
with ProgressBar():
    missing_count_val = missing_count.compute()
# Out:
# [####################################    ] | 92% Completed |  1min 39.1s
# C:\Users\HP\anaconda3\lib\multiprocessing\pool.py:125: DtypeWarning: Columns (18,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   result = (True, func(*args, **kwds))
# [########################################] | 100% Completed |  1min 41.1s

# %%
missing_count_val
# Out:
# Summons Number                         0.000000
# Plate ID                               0.006739
# Registration State                     0.000000
# Plate Type                             0.000000
# Issue Date                             0.000000
# Violation Code                         0.000000
# Vehicle Body Type                      0.395361
# Vehicle Make                           0.676199
# Issuing Agency                         0.000000
# Street Code1                           0.000000
# Street Code2                           0.000000
# Street Code3                           0.000000
# Vehicle Expiration Date                0.000000
# Violation Location                    19.183510
# Violation Precinct                     0.000000
# Issuer Precinct                        0.000000
# Issuer Code                            0.000000
# Issuer Command                        19.093212
# Issuer Squad                          19.101506
# Violation Time                         0.000583
# ...

# %%
columns_to_drop = missing_count_val[missing_count_val > 60].index

# %%
columns_to_drop
# Out:
# Index(['Time First Observed', 'Intersecting Street', 'Violation Legal Code',
#        'Unregistered Vehicle?', 'Meter Number',
#        'No Standing or Stopping Violation', 'Hydrant Violation',
#        'Double Parking Violation'],
#       dtype='object')

# %%
with ProgressBar():
        df_dropped = df.drop(columns_to_drop,axis=1).persist()
# Out:
# [#####################################   ] | 93% Completed |  2min 29.2s
# C:\Users\HP\anaconda3\lib\site-packages\dask\core.py:121: DtypeWarning: Columns (18,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   return func(*(_execute_task(a, cache) for a in args))
# [########################################] | 100% Completed |  2min 35.9s

# %%
df_dropped
# Out:
# Dask DataFrame Structure:
#                Summons Number Plate ID Registration State Plate Type Issue Date Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1 Street Code2 Street Code3 Vehicle Expiration Date Violation Location Violation Precinct Issuer Precinct Issuer Code Issuer Command Issuer Squad Violation Time Violation County Violation In Front Of Or Opposite House Number Street Name Date First Observed Law Section Sub Division Days Parking In Effect     From Hours In Effect To Hours In Effect Vehicle Color Vehicle Year Feet From Curb Violation Post Code Violation Description
# npartitions=33
# ...

# %%
import pandas as pd

# %%
fy14 = dd.read_csv("./archive/Parking_Violations_Issued_-_Fiscal_Year_2014__August_2013___June_2014_.csv")
fy15 = dd.read_csv("./archive/Parking_Violations_Issued_-_Fiscal_Year_2015.csv")
fy16 = dd.read_csv("./archive/Parking_Violations_Issued_-_Fiscal_Year_2016.csv")
fy17 = dd.read_csv("./archive/Parking_Violations_Issued_-_Fiscal_Year_2017.csv")

# %%
fy17.dtypes
# Out:
# Summons Number                         int64
# Plate ID                              object
# Registration State                    object
# Plate Type                            object
# Issue Date                            object
# Violation Code                         int64
# Vehicle Body Type                     object
# Vehicle Make                          object
# Issuing Agency                        object
# Street Code1                           int64
# Street Code2                           int64
# Street Code3                           int64
# Vehicle Expiration Date                int64
# Violation Location                   float64
# Violation Precinct                     int64
# Issuer Precinct                        int64
# Issuer Code                            int64
# Issuer Command                        object
# Issuer Squad                          object
# Violation Time                        object
# Time First Observed                   object
# ...

# %%
fy15
# Out:
# Dask DataFrame Structure:
#                Summons Number Plate ID Registration State Plate Type Issue Date Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1 Street Code2 Street Code3 Vehicle Expiration Date Violation Location Violation Precinct Issuer Precinct Issuer Code Issuer Command Issuer Squad Violation Time Time First Observed Violation County Violation In Front Of Or Opposite House Number Street Name Intersecting Street Date First Observed Law Section Sub Division Violation Legal Code Days Parking In Effect     From Hours In Effect To Hours In Effect Vehicle Color Unregistered Vehicle? Vehicle Year Meter Number Feet From Curb Violation Post Code Violation Description No Standing or Stopping Violation Hydrant Violation Double Parking Violation Latitude Longitude Community Board Community Council  Census Tract      BIN      BBL      NTA
# npartitions=45
# ...

# %%
from functools import reduce

# %%
columns = [set(fy14.columns),set(fy15.columns),set(fy16.columns),set(fy17.columns)]
common_columns = list(reduce(lambda x,y: x.intersection(y),columns))

# %%
common_columns
# Out:
# ['Days Parking In Effect    ',
#  'Violation Post Code',
#  'Street Code1',
#  'Time First Observed',
#  'Registration State',
#  'Issue Date',
#  'Issuer Squad',
#  'Violation Legal Code',
#  'Sub Division',
#  'Issuing Agency',
#  'Violation County',
#  'Street Code3',
#  'Vehicle Year',
#  'Vehicle Expiration Date',
#  'Vehicle Color',
#  'Plate Type',
#  'Vehicle Make',
#  'Issuer Command',
#  'Violation Description',
#  'Feet From Curb',
#  'From Hours In Effect',
#  'Meter Number',
#  'Issuer Precinct',
#  'Unregistered Vehicle?',
#  'Vehicle Body Type',
#  'Double Parking Violation',
#  'Violation Precinct',
#  'Violation Location',
#  'Issuer Code',
#  'Plate ID',
#  'To Hours In Effect',
#  'Date First Observed',
#  'Street Name',
#  'No Standing or Stopping Violation',
#  'House Number',
#  'Hydrant Violation',
#  'Street Code2',
#  'Violation Time',
#  'Summons Number',
#  'Law Section',
#  'Violation Code',
#  'Violation In Front Of Or Opposite',
# ...

# %%
fy17[common_columns].head()
# Out:
#   Days Parking In Effect     Violation Post Code  Street Code1  \
# 0                        NaN                 NaN             0
# 1                        NaN                 NaN             0
# 2                        NaN                 NaN             0
# 3                          Y                  04         10610
# 4                          Y                31 6         10510
#
#   Time First Observed Registration State  Issue Date Issuer Squad  \
# 0                 NaN                 NY  07/10/2016          NaN
# 1                 NaN                 NY  07/08/2016          NaN
# 2                 NaN                 NY  08/23/2016          NaN
# 3                 NaN                 NY  06/14/2017            J
# 4                 NaN                 NY  11/21/2016            M
#
#   Violation Legal Code Sub Division Issuing Agency  ...  \
# 0                    T            D              V  ...
# 1                    T            D              V  ...
# ...

# %%
fy15[common_columns].head()
# Out:
#   Days Parking In Effect     Violation Post Code  Street Code1  \
# 0                      Y Y Y                A 77         20390
# 1                      YYYYY                 CC3         27790
# 2                        NaN                J 32          8130
# 3                      YYYYY                01 4         59990
# 4                    YYYYYYY                19 7         36090
#
#   Time First Observed Registration State  Issue Date Issuer Squad  \
# 0                 NaN                 NY  10/01/2014           A2
# 1                 NaN                 NY  03/06/2015            B
# 2                 NaN                 NY  07/28/2014            L
# 3                 NaN                 NY  04/13/2015            D
# 4                 NaN                 NY  05/19/2015            X
#
#    Violation Legal Code Sub Division Issuing Agency  ...  \
# 0                   NaN           d1              T  ...
# 1                   NaN            c              T  ...
# ...

# %%
fy16[common_columns].head()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\dask\core.py:121: DtypeWarning: Columns (17,18,20,21,22,23,29,30,31,32,36,38,39) have mixed types.Specify dtype option on import or set low_memory=False.
#   return func(*(_execute_task(a, cache) for a in args))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-72149d645e48> in <module>
# ----> 1 fy16[common_columns].head()
#
# ~\anaconda3\lib\site-packages\dask\dataframe\core.py in head(self, n, npartitions, compute)
#    1004             Whether to compute the result, default is True.
#    1005         """
# -> 1006         return self._head(n=n, npartitions=npartitions, compute=compute, safe=True)
#    1007
#    1008     def _head(self, n, npartitions, compute, safe):
#
# ~\anaconda3\lib\site-packages\dask\dataframe\core.py in _head(self, n, npartitions, compute, safe)
#    1037
#    1038         if compute:
# ...

# %%
import numpy as np

# %%
dtype_tuples = [(x,np.str) for x in common_columns]

dtypes = dict(dtype_tuples)

# %%
convert_dict = {'Plate ID': object,
 'Street Name': object,
 'Vehicle Make': object,
 'Street Code2': int,
 'Plate Type': object,
 'Violation Location': float,
 'Violation Code': int,
 'Violation In Front Of Or Opposite': object,
 'Issuer Command': object,
 'Vehicle Body Type': object,
 'Feet From Curb': int,
 'No Standing or Stopping Violation': float,
 'Street Code3': int,
 'Street Code1': int,
 'Issuer Code': int,
 'House Number': object,
 'Hydrant Violation': float,
 'Law Section': int,
 'Intersecting Street': object,
 'To Hours In Effect': object,
 'Violation Precinct': int,
 'Days Parking In Effect    ': object,
 'Registration State': object,
 'Violation Legal Code': float,
 'Vehicle Expiration Date': object,
 'Violation Description': object,
 'Time First Observed': object,
 'Date First Observed': object,
 'From Hours In Effect': object,
 'Sub Division': object,
 'Unregistered Vehicle?': float,
 'Violation Time': object,
 'Issuer Precinct': int,
 'Meter Number': object,
 'Violation County': object,
 'Violation Post Code': object,
 'Vehicle Year': int,
 'Vehicle Color': object,
 'Issue Date': object,
 'Issuing Agency': object,
 'Summons Number': int,
 'Issuer Squad': object,
 'Double Parking Violation': float}convert_dict = {'Plate ID': object,
 'Street Name': object,
 'Vehicle Make': object,
 'Street Code2': int,
 'Plate Type': object,
 'Violation Location': float,
 'Violation Code': int,
 'Violation In Front Of Or Opposite': object,
 'Issuer Command': object,
 'Vehicle Body Type': object,
 'Feet From Curb': int,
 'No Standing or Stopping Violation': float,
 'Street Code3': int,
 'Street Code1': int,
 'Issuer Code': int,
 'House Number': object,
 'Hydrant Violation': float,
 'Law Section': int,
 'Intersecting Street': object,
 'To Hours In Effect': object,
 'Violation Precinct': int,
 'Days Parking In Effect    ': object,
 'Registration State': object,
 'Violation Legal Code': float,
 'Vehicle Expiration Date': object,
 'Violation Description': object,
 'Time First Observed': object,
 'Date First Observed': object,
 'From Hours In Effect': object,
 'Sub Division': object,
 'Unregistered Vehicle?': float,
 'Violation Time': object,
 'Issuer Precinct': int,
 'Meter Number': object,
 'Violation County': object,
 'Violation Post Code': object,
 'Vehicle Year': int,
 'Vehicle Color': object,
 'Issue Date': object,
 'Issuing Agency': object,
 'Summons Number': int,
 'Issuer Squad': object,
 'Double Parking Violation': float}
# Out:
#   File "<ipython-input-73-63631e9b787b>", line 43
#     'Double Parking Violation': float}convert_dict = {'Plate ID': object,
#                                       ^
# SyntaxError: invalid syntax

# %%
fy14 = dd.read_csv("./archive/Parking_Violations_Issued_-_Fiscal_Year_2014__August_2013___June_2014_.csv",dtype=dtypes)

# %%
fy14.head()
# Out:
#   Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0     1283294138  GBB9093                 NY        PAS  08/04/2013
# 1     1283294151  62416MB                 NY        COM  08/04/2013
# 2     1283294163  78755JZ                 NY        COM  08/05/2013
# 3     1283294175  63009MA                 NY        COM  08/05/2013
# 4     1283294187  91648MC                 NY        COM  08/08/2013
#
#   Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1  \
# 0             46              SUBN         AUDI              P        37250
# 1             46               VAN         FORD              P        37290
# 2             46               P-U        CHEVR              P        37030
# 3             46               VAN         FORD              P        37270
# 4             41              TRLR          GMC              P        37240
#
#    ... Hydrant Violation Double Parking Violation Latitude Longitude  \
# ...

# %%
fy16 = dd.read_csv("./archive/Parking_Violations_Issued_-_Fiscal_Year_2016.csv",dtype=dtypes)

# %%
fy16.head()
# Out:
#   Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0     1363745270  GGY6450                 99        PAS  07/09/2015
# 1     1363745293   KXD355                 SC        PAS  07/09/2015
# 2     1363745438  JCK7576                 PA        PAS  07/09/2015
# 3     1363745475  GYK7658                 NY        OMS  07/09/2015
# 4     1363745487  GMT8141                 NY        PAS  07/09/2015
#
#   Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1  \
# 0             46               SDN        HONDA              P            0
# 1             21              SUBN        CHEVR              P        55730
# 2             21               SDN        ME/BE              P        42730
# 3             21              SUBN        NISSA              P        58130
# 4             21               P-U        LINCO              P        58130
#
#    ... Hydrant Violation Double Parking Violation Latitude Longitude  \
# ...

# %%
complete_data = dd.read_csv("./archive/*.csv",dtype=dtypes,usecols=common_columns)

# %%
x=complete_data.columns

# %%
obj_x=['Plate ID', 'Registration State', 'Plate Type',
       'Issue Date','Vehicle Body Type', 'Vehicle Make',
       'Issuing Agency','Issuer Command', 'Issuer Squad',
       'Violation Time', 'Time First Observed', 'Violation County',
       'Violation In Front Of Or Opposite', 'House Number', 'Street Name',
       'Intersecting Street','Sub Division', 'Violation Legal Code', 'Days Parking In Effect    ',
       'From Hours In Effect', 'To Hours In Effect', 'Vehicle Color', 
       'Meter Number','Violation Post Code', 'Violation Description']

# %%
int_x =['Summons Number','Violation Code','Street Code1', 'Street Code2', 'Street Code3',
       'Vehicle Expiration Date', 'Violation Precinct','Issuer Precinct', 'Issuer Code','Date First Observed',
        'Law Section','Vehicle Year','Feet From Curb']

# %%
float_x = ['Violation Location','Unregistered Vehicle?','No Standing or Stopping Violation', 'Hydrant Violation',
       'Double Parking Violation',]

# %%
complete_data[obj_x]=complete_data[obj_x].astype(object)
complete_data[int_x]=complete_data[int_x].astype('int64')
complete_data[float_x] =complete_data[float_x].astype('float64')

# %%
complete_data.shape
# Out:
# (Delayed('int-f8c9c1d9-30b7-4de8-9d37-0da912293b01'), 43)

# %%
# Out:
# Dask Series Structure:
# npartitions=1
# Date First Observed    int64
# Violation Time           ...
# dtype: int64
# Dask Name: dataframe-count-agg, 67 tasks

# %% [markdown]
# # Reading data from HDFS

# %%
complete_data = dd.read_csv("hdfs://localhost/archive/*.csv",dtype=dtypes,usecols=common_columns)

# %% [markdown]
# # Reading data from S3

# %%
complete_data = dd.read_csv("s3://exam prac/archive/*.csv",dtype=dtypes,uscols=common_columns)
